# %%
import pandas as pd
from mysql import connector
from dotenv import load_dotenv
import os
from datetime import datetime

import warnings

# %% [markdown]
# # Coursera

# %%
load_dotenv()

username = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST')
DB = 'Coursera'

# %%
conn = connector.connect(user=username,
                         password=password,
                         host=host,
                         database=DB)

# %%
df_compras = pd.read_sql('''SELECT * FROM compras;''', conn)
# Out:
# /tmp/ipykernel_891/1989898025.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_compras = pd.read_sql('''SELECT * FROM compras;''', conn)

# %%
df_compras
# Out:
#    id_compra  id_curso  id_usuario      fecha fecha_visualizacion  \
# 0         25         8           6 2023-10-16          2023-10-16
# 1         26         4           5 2023-10-16          2023-10-16
# 2         27         5           3 2023-10-16          2023-10-16
# 3         28         1           3 2023-10-16          2023-10-16
# 4         29         5           4 2023-10-16          2023-10-16
# 5         30         3           7 2023-10-16          2023-10-16
# 6         31         6           1 2023-10-16          2023-10-16
# 7         32         2           8 2023-10-16          2023-10-16
# 8         33         1           8 2023-10-16          2023-10-16
# 9         34         8           2 2023-10-16          2023-10-16
#
#   fecha_inicio  fecha_fin interrupcion  longitud    latitud  calificacion  \
# 0   2023-10-16 2023-10-16         None  -75.2211  -0.705623             8
# 1   2023-10-16 2023-10-16         None  -72.4756   0.593246             4
# 2   2023-10-16 2023-10-16         None  -73.1557  11.862200             1
# 3   2023-10-16 2023-10-16         None  -72.7995   6.186810             8
# 4   2023-10-16 2023-10-16         None  -72.3695   8.961610             6
# 5   2023-10-16 2023-10-16         None  -67.1479  -3.851860            10
# 6   2023-10-16 2023-10-16         None  -72.6311   0.710913             4
# 7   2023-10-16 2023-10-16         None  -75.1610   7.929000             3
# 8   2023-10-16 2023-10-16         None  -68.3231  -2.492100             8
# 9   2023-10-16 2023-10-16         None  -67.6012   7.570650             1
#
#    costo_servicio
# 0           35.64
# 1           10.91
# 2           81.03
# 3           51.11
# 4           33.24
# 5           36.37
# 6           54.09
# 7           72.94
# 8           72.91
# 9           97.13

# %%
df_compras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_compra            10 non-null     int64
#  1   id_curso             10 non-null     int64
#  2   id_usuario           10 non-null     int64
#  3   fecha                10 non-null     datetime64[ns]
#  4   fecha_visualizacion  10 non-null     datetime64[ns]
#  5   fecha_inicio         10 non-null     datetime64[ns]
#  6   fecha_fin            10 non-null     datetime64[ns]
#  7   interrupcion         0 non-null      object
#  8   longitud             10 non-null     float64
#  9   latitud              10 non-null     float64
#  10  calificacion         10 non-null     int64
#  11  costo_servicio       10 non-null     float64
# dtypes: datetime64[ns](4), float64(3), int64(4), object(1)
# memory usage: 1.1+ KB

# %%
filename = DB+'_' + str(datetime.now().date()) + '.csv'
filename
# Out:
# 'Coursera_2023-10-17.csv'

# %%
df_compras.to_csv(filename, index=False, date_format='%Y-%M-%d')

# %% [markdown]
# # Udemy

# %%
DB = 'Udemy'

# %%
conn = connector.connect(user=username,
                         password=password,
                         host=host,
                         database=DB)

# %%
df_compras = pd.read_sql("SELECT * FROM compras;", conn)
# Out:
# /tmp/ipykernel_891/1021947071.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_compras = pd.read_sql("SELECT * FROM compras;", conn)

# %%
df_compras
# Out:
#    id_compra  id_curso  id_usuario               fecha fecha_visualizacion  \
# 0          1         1         114 2022-09-15 14:00:00 2022-09-16 08:30:00
# 1          2         5         115 2022-08-25 12:45:00 2022-08-26 11:00:00
# 2          3         6         116 2022-07-30 10:30:00 2022-07-31 13:45:00
# 3          4         7         117 2022-06-10 11:00:00 2022-06-11 09:15:00
# 4          5         8         118 2022-05-20 09:15:00 2022-05-21 08:30:00
# 5          6         9         119 2022-04-25 13:45:00 2022-04-26 09:30:00
# 6          7        11         120 2022-03-15 15:00:00 2022-03-16 13:15:00
# 7          8         6         111 2022-03-08 10:00:00 2022-03-09 09:15:00
# 8          9         2         111 2022-02-15 09:30:00 2022-02-16 08:45:00
#
#          fecha_inicio           fecha_fin              interrupcion  longitud  \
# 0 2022-09-16 09:00:00 2022-09-25 12:30:00  Problema de conectividad   48.8566
# 1 2022-08-26 11:15:00 2022-09-04 15:30:00                      None   40.7128
# 2 2022-07-31 14:00:00 2022-08-09 16:45:00      Interrupción técnica   34.0522
# 3 2022-06-11 09:30:00 2022-06-20 14:30:00                      None   41.8781
# 4 2022-05-21 09:00:00 2022-05-30 12:45:00  Problema de conectividad   51.5074
# 5 2022-04-26 10:00:00 2022-05-05 14:15:00                      None   35.6828
# 6 2022-03-16 13:30:00 2022-03-25 17:45:00                      None   52.5200
# 7 2022-03-09 09:30:00 2022-03-18 11:45:00                      None   40.7128
# 8 2022-02-16 09:00:00 2022-02-25 12:30:00                      None   34.0522
#
#     latitud  id_plataforma  calificacion  costo_servicio
# 0    2.3522              2             4           44.99
# 1  -74.0060              1             3           34.99
# 2 -118.2440              3             4           39.99
# 3  -87.6298              1             5           59.99
# 4   -0.1278              2             4           29.99
# 5  139.7590              3             3           49.99
# 6   13.4050              1             4           39.99
# 7  -74.0060              2             5           59.99
# 8 -118.2440              1             4           49.99

# %%
df_compras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_compra            9 non-null      int64
#  1   id_curso             9 non-null      int64
#  2   id_usuario           9 non-null      int64
#  3   fecha                9 non-null      datetime64[ns]
#  4   fecha_visualizacion  9 non-null      datetime64[ns]
#  5   fecha_inicio         9 non-null      datetime64[ns]
#  6   fecha_fin            9 non-null      datetime64[ns]
#  7   interrupcion         3 non-null      object
#  8   longitud             9 non-null      float64
#  9   latitud              9 non-null      float64
#  10  id_plataforma        9 non-null      int64
#  11  calificacion         9 non-null      int64
#  12  costo_servicio       9 non-null      float64
# dtypes: datetime64[ns](4), float64(3), int64(5), object(1)
# memory usage: 1.0+ KB

# %%
filename = DB+'_' + str(datetime.now().date()) + '.csv'
filename
# Out:
# 'Udemy_2023-10-17.csv'

# %%
df_compras.to_csv(filename, index=False, date_format='%Y-%M-%d')

# %%
str(datetime.now())
# Out:
# '2023-10-17 17:31:28.624208'

# %%
cities = pd.read_csv('cities.csv')
cities
# Out:
#                       CIUDAD CIUDADGEO2 CIUDADGEO3            PAIS PAISGEO2  \
# 0                 Nueva York         NY        NYC  Estados Unidos       US
# 1                Los Ángeles         CA        LAX  Estados Unidos       US
# 2                    Chicago         IL        CHI  Estados Unidos       US
# 3                    Houston         TX        HOU  Estados Unidos       US
# 4                    Phoenix         AZ        PHX  Estados Unidos       US
# 5               Philadelphia         PA        PHL  Estados Unidos       US
# 6                San Antonio         TX        SAT  Estados Unidos       US
# 7                  San Diego         CA        SAN  Estados Unidos       US
# 8                     Dallas         TX        DFW  Estados Unidos       US
# 9                   San José         CA        SJC  Estados Unidos       US
# 10              Jacksonville         FL        JAX  Estados Unidos       US
# 11              Indianápolis         IN        IND  Estados Unidos       US
# 12                    Austin         TX        AUS  Estados Unidos       US
# 13             San Francisco         CA        SFO  Estados Unidos       US
# 14                  Columbus         OH        CMH  Estados Unidos       US
# 15                 Charlotte         NC        CLT  Estados Unidos       US
# 16                Fort Worth         TX        FTW  Estados Unidos       US
# 17                   Detroit         MI        DTW  Estados Unidos       US
# 18                   El Paso         TX        ELP  Estados Unidos       US
# 19                   Memphis         TN        MEM  Estados Unidos       US
# 20                 Baltimore         MD        BWI  Estados Unidos       US
# 21                    Boston         MA        BOS  Estados Unidos       US
# 22                   Seattle         WA        SEA  Estados Unidos       US
# 23                Washington         DC        DCA  Estados Unidos       US
# 24                 Nashville         TN        BNA  Estados Unidos       US
# 25                    Denver         CO        DEN  Estados Unidos       US
# 26                 Milwaukee         WI        MKE  Estados Unidos       US
# 27                  Portland         OR        PDX  Estados Unidos       US
# 28             Oklahoma City         OK        OKC  Estados Unidos       US
# 29                 Las Vegas         NV        LAS  Estados Unidos       US
# 30               Albuquerque         NM        ABQ  Estados Unidos       US
# 31                    Bogota         BO        BOG        Colombia       CO
# 32                  Medellin         ME       MED         Colombia       CO
# 33                      Cali         CA        CAL        Colombia       CO
# 34  San Andres y Providencia         SA        SAP        Colombia       CO
# 35                 Cartagena         CT        CTG        Colombia       CO
# 36              Barranquilla         BA        BAQ        Colombia       CO
# 37               Santa Marta         SM        SMT        Colombia       CO
#
#    PAISGEO3
# 0       USA
# 1       USA
# 2       USA
# 3       USA
# 4       USA
# 5       USA
# 6       USA
# 7       USA
# 8       USA
# 9       USA
# 10      USA
# 11      USA
# 12      USA
# 13      USA
# 14      USA
# 15      USA
# 16      USA
# 17      USA
# 18      USA
# 19      USA
# 20      USA
# 21      USA
# 22      USA
# 23      USA
# 24      USA
# 25      USA
# 26      USA
# 27      USA
# 28      USA
# 29      USA
# 30      USA
# 31      COL
# 32      COL
# 33      COL
# 34      COL
# 35      COL
# 36      COL
# 37      COL

# %%
city = cities.sample()
city
# Out:
#     CIUDAD CIUDADGEO2 CIUDADGEO3            PAIS PAISGEO2 PAISGEO3
# 21  Boston         MA        BOS  Estados Unidos       US      USA

# %%
city['CIUDAD'].values
# Out:
# array(['Boston'], dtype=object)
